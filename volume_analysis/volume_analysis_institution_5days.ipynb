# %%
# %load_ext autoreload
# %autoreload
import time, datetime
import os
import pandas as pd

pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   import sys

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
rootPath = "/content/drive/My Drive/주식과빅데이터/workspace"
# Out:
# Mounted at /content/drive

# %%
def get_volumeKospiHistory(rootPath, code, name, start_date, end_date):        
    filePath = rootPath + "/Kospi/" + str(code).zfill(6) + "_" + name + ".csv"
    data = pd.read_csv(filePath, engine='python')
    
    datetime_index = pd.to_datetime(data['date'])
    df=data.set_index(datetime_index)
#     df.drop('date',axis=1,inplace=True)
    
    df = df.loc[start_date:end_date]
    
    return df

# %%
def get_priceHistory(rootPath, code, name, start_date, end_date):
    filePath = rootPath + "/Price_Edit/" + str(code).zfill(6) + "_" + name + ".csv"
    data = pd.read_csv(filePath, engine='python')
    
    datetime_index = pd.to_datetime(data['date'])
    df=data.set_index(datetime_index)
#     df.drop('date',axis=1,inplace=True)
    
    df = df.loc[start_date:end_date]
    
    return df

# %%
def get_volumeKosdaqHistory(rootPath, code, name, start_date, end_date):
    filePath = rootPath + "/Kosdaq/" + str(code).zfill(6) + "_" + name + ".csv"
    data = pd.read_csv(filePath, engine='python')
    
    datetime_index = pd.to_datetime(data['date'])
    df=data.set_index(datetime_index)
#     df.drop('date',axis=1,inplace=True)
    
    df = df.loc[start_date:end_date]
    
    return df

# %%
code = "008500"
name = "일정실업"
start_date = '2010-01-01'
end_date = '2019-12-31'

def getKospiMergedTab(rootPath, code, name, start_date, end_date):
    vol = get_volumeKospiHistory(rootPath, code, name, start_date, end_date).fillna(0)
    p = get_priceHistory(rootPath, code,name, start_date, end_date).fillna(0)
    df = pd.concat([vol, p], axis=1, join='inner')
    
    return df

def getKosdaqMergedTab(rootPath, code, name, start_date, end_date):
    vol = get_volumeKosdaqHistory(rootPath, code, name, start_date, end_date).fillna(0)
    p = get_priceHistory(rootPath, code,name, start_date, end_date).fillna(0)
    df = pd.concat([vol, p], axis=1, join='inner')
    
    return df

df008500merged = getKospiMergedTab(rootPath, code, name, start_date, end_date)

# %%
def accumConsecutiveCount(df):
    df['accum'] = (df['NetBuyAmount_Inst'] > 0).astype(int)
    last_index = df.index[0]
    init_index = last_index + pd.DateOffset(1)
    for index, row in df[init_index:].iterrows():
        if df.loc[index].accum > 0:
            df.loc[index,'accum'] = df.loc[last_index, 'accum'] + 1
        last_index = index
    return df

df008500 = accumConsecutiveCount(df008500merged)

# %%
def computeRevenue(df):
    output_df = pd.DataFrame(columns=['매수일', '6th', '7th','8th','9th','10th','11th','12th','13th','14th','15th'])
    for i, _ in df[df['accum']>=5].iterrows():
        next_day = df.index.get_loc(i) + 1
        if (next_day+10) < df.shape[0]:                
            tmp_v = list()
            base_day = df.iloc[next_day-6].at['date'][0]
            tmp_v.append(base_day)
            base_price = df.iloc[next_day]['Open']
            for _ in range(10):
                close_price = df.iloc[next_day]['Close']
                revenue = ((close_price - base_price) * 100) / base_price
                tmp_v.append(revenue)
                next_day = next_day + 1
            tmp_series = pd.Series(tmp_v, index = output_df.columns)
            output_df = output_df.append(tmp_series, ignore_index=True)
    return output_df
# df = computeRevenue(df008500)

# file_path = rootPath + '/output/raw_' + code + "_" + name + ".csv"
# df.to_csv(file_path, index = False, header=True)

# %%
def getSummary_max(code, name, df):
    output_df = pd.DataFrame(columns=['종목명','종목코드','6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
    tmpList = list()
    tmpList.append(code)
    tmpList.append(name)
    for i in range(6, 16, 1):
        df_min = df[str(i)+'th'].max()
        tmpList.append(df_min)
    return tmpList

def getSummary_min(code, name, df):
    output_df = pd.DataFrame(columns=['종목명','종목코드','6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
    tmpList = list()
    tmpList.append(code)
    tmpList.append(name)
    for i in range(6, 16, 1):
        df_max = df[str(i)+'th'].min()
        tmpList.append(df_max)
    return tmpList

def getSummary_avg(code, name, df):
    output_df = pd.DataFrame(columns=['종목명','종목코드','6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
    tmpList = list()
    tmpList.append(code)
    tmpList.append(name)
    for i in range(6, 16, 1):
        df_mean = df[str(i)+'th'].mean()
        tmpList.append(df_mean)
    return tmpList

def getSummary_med(code, name, df):
    output_df = pd.DataFrame(columns=['종목명','종목코드','6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
    tmpList = list()
    tmpList.append(code)
    tmpList.append(name)
    for i in range(6, 16, 1):
        df_median = df[str(i)+'th'].median()
        tmpList.append(df_median)
    return tmpList

def getSummary_prob(code, name, df):
    output_df = pd.DataFrame(columns=['종목명','종목코드','6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
    tmpList = list()
    tmpList.append(code)
    tmpList.append(name)
    for i in range(6, 16, 1):
        df_prob = df[df[str(i)+'th']>0].shape[0]/df.shape[0]
        tmpList.append(df_prob)
    return tmpList

# %%
start_date = '2010-01-01'
end_date = '2019-12-31'

# %%
min_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
max_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
avg_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
med_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
prob_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])


file_list = os.listdir(rootPath+"/Kospi/")
kospi_file_list_csv = [file for file in file_list if file.endswith(".csv")]
total_day = len(kospi_file_list_csv)
total_process_time = 0
for i,v in enumerate(kospi_file_list_csv):
  try:
    code = v[:6]
    name = v[7:-4]
    start_time = time.time()
    dfMerged = getKospiMergedTab(rootPath, code, name, start_date, end_date)
    dfCount = accumConsecutiveCount(dfMerged)
    dfRevenue = computeRevenue(dfCount)
    if dfRevenue.shape[0] > 0:
      # file_path = rootPath + '/output/raw_' + code + "_" + name + ".csv"
      # dfRevenue.to_csv(file_path, index = False, header=True)
      tmp_series_max = pd.Series(getSummary_max(code, name, dfRevenue), index = max_output_df.columns)
      max_output_df = max_output_df.append(tmp_series_max, ignore_index=True)

      tmp_series_min = pd.Series(getSummary_min(code, name, dfRevenue), index = min_output_df.columns)
      min_output_df = min_output_df.append(tmp_series_min, ignore_index=True)

      tmp_series_avg = pd.Series(getSummary_avg(code, name, dfRevenue), index = avg_output_df.columns)
      avg_output_df = avg_output_df.append(tmp_series_avg, ignore_index=True)

      tmp_series_med = pd.Series(getSummary_med(code, name, dfRevenue), index = med_output_df.columns)
      med_output_df = med_output_df.append(tmp_series_med, ignore_index=True)

      tmp_series_prob = pd.Series(getSummary_prob(code, name, dfRevenue), index = prob_output_df.columns)
      prob_output_df = prob_output_df.append(tmp_series_prob, ignore_index=True)

    end_time = time.time()
    processed_time = int(end_time - start_time)
    total_process_time += processed_time
    print("{}/{} {}-{} Processed(처리시간:{}sec, 누적시간:{}sec) - 대상거래일수:{}, 5연속순매수일:{}".format(i+1, total_day, code, name, processed_time, total_process_time, dfMerged.shape[0], dfRevenue.shape[0]))
  except Exception as e: 
    print(e)
    continue    
    
file_path_max = rootPath + '/output/summary_5days_kospi_max.csv'
max_output_df.to_csv(file_path_max, index = False, header=True)

file_path_min = rootPath + '/output/summary_5days_kospi_min.csv'
min_output_df.to_csv(file_path_min, index = False, header=True)

file_path_avg = rootPath + '/output/summary_5days_kospi_avg.csv'
avg_output_df.to_csv(file_path_avg, index = False, header=True)

file_path_med = rootPath + '/output/summary_5days_kospi_med.csv'
med_output_df.to_csv(file_path_med, index = False, header=True)

file_path_prob = rootPath + '/output/summary_5days_kospi_prob.csv'
prob_output_df.to_csv(file_path_prob, index = False, header=True)
# Out:
# 1/775 005930-삼성전자 Processed(처리시간:14sec, 누적시간:14sec) - 대상거래일수:2466, 5연속순매수일:230
# 2/775 000660-SK하이닉스 Processed(처리시간:14sec, 누적시간:28sec) - 대상거래일수:2466, 5연속순매수일:241
# 3/775 207940-삼성바이오로직스 Processed(처리시간:8sec, 누적시간:36sec) - 대상거래일수:2466, 5연속순매수일:86
# 4/775 051910-LG화학 Processed(처리시간:14sec, 누적시간:50sec) - 대상거래일수:2466, 5연속순매수일:230
# 5/775 035420-NAVER Processed(처리시간:16sec, 누적시간:66sec) - 대상거래일수:2466, 5연속순매수일:320
# 6/775 068270-셀트리온 Processed(처리시간:14sec, 누적시간:80sec) - 대상거래일수:2466, 5연속순매수일:216
# 7/775 005380-현대차 Processed(처리시간:14sec, 누적시간:94sec) - 대상거래일수:2466, 5연속순매수일:241
# 8/775 006400-삼성SDI Processed(처리시간:15sec, 누적시간:109sec) - 대상거래일수:2466, 5연속순매수일:286
# 9/775 035720-카카오 Processed(처리시간:17sec, 누적시간:126sec) - 대상거래일수:2466, 5연속순매수일:315
# 10/775 051900-LG생활건강 Processed(처리시간:16sec, 누적시간:142sec) - 대상거래일수:2466, 5연속순매수일:294
# 11/775 028260-삼성물산 Processed(처리시간:11sec, 누적시간:153sec) - 대상거래일수:2466, 5연속순매수일:187
# 12/775 036570-엔씨소프트 Processed(처리시간:16sec, 누적시간:169sec) - 대상거래일수:2466, 5연속순매수일:301
# 13/775 012330-현대모비스 Processed(처리시간:16sec, 누적시간:185sec) - 대상거래일수:2466, 5연속순매수일:301
# 14/775 017670-SK텔레콤 Processed(처리시간:17sec, 누적시간:202sec) - 대상거래일수:2466, 5연속순매수일:357
# 15/775 000270-기아차 Processed(처리시간:15sec, 누적시간:217sec) - 대상거래일수:2466, 5연속순매수일:272
# 16/775 005490-POSCO Processed(처리시간:16sec, 누적시간:233sec) - 대상거래일수:2466, 5연속순매수일:296
# 17/775 105560-KB금융 Processed(처리시간:16sec, 누적시간:249sec) - 대상거래일수:2466, 5연속순매수일:301
# 18/775 096770-SK이노베이션 Processed(처리시간:14sec, 누적시간:263sec) - 대상거래일수:2466, 5연속순매수일:237
# 19/775 034730-SK Processed(처리시간:15sec, 누적시간:278sec) - 대상거래일수:2466, 5연속순매수일:253
# 20/775 055550-신한지주 Processed(처리시간:15sec, 누적시간:293sec) - 대상거래일수:2466, 5연속순매수일:249
# 21/775 003550-LG Processed(처리시간:17sec, 누적시간:310sec) - 대상거래일수:2466, 5연속순매수일:345
# 22/775 326030-SK바이오팜 Processed(처리시간:4sec, 누적시간:314sec) - 대상거래일수:2466, 5연속순매수일:0
# 23/775 032830-삼성생명 Processed(처리시간:18sec, 누적시간:332sec) - 대상거래일수:2466, 5연속순매수일:372
# 24/775 066570-LG전자 Processed(처리시간:16sec, 누적시간:348sec) - 대상거래일수:2466, 5연속순매수일:310
# 25/775 015760-한국전력 Processed(처리시간:15sec, 누적시간:363sec) - 대상거래일수:2466, 5연속순매수일:272
# 26/775 018260-삼성에스디에스 Processed(처리시간:11sec, 누적시간:374sec) - 대상거래일수:2466, 5연속순매수일:185
# 27/775 251270-넷마블 Processed(처리시간:7sec, 누적시간:381sec) - 대상거래일수:2466, 5연속순매수일:87
# 28/775 033780-KT&G Processed(처리시간:16sec, 누적시간:397sec) - 대상거래일수:2466, 5연속순매수일:298
# 29/775 090430-아모레퍼시픽 Processed(처리시간:17sec, 누적시간:414sec) - 대상거래일수:2466, 5연속순매수일:335
# 30/775 009150-삼성전기 Processed(처리시간:16sec, 누적시간:430sec) - 대상거래일수:2466, 5연속순매수일:295
# 31/775 086790-하나금융지주 Processed(처리시간:15sec, 누적시간:445sec) - 대상거래일수:2466, 5연속순매수일:279
# 32/775 000810-삼성화재 Processed(처리시간:16sec, 누적시간:461sec) - 대상거래일수:2466, 5연속순매수일:303
# 33/775 010130-고려아연 Processed(처리시간:15sec, 누적시간:476sec) - 대상거래일수:2466, 5연속순매수일:258
# 34/775 010950-S-Oil Processed(처리시간:16sec, 누적시간:492sec) - 대상거래일수:2466, 5연속순매수일:284
# 35/775 018880-한온시스템 Processed(처리시간:16sec, 누적시간:508sec) - 대상거래일수:2466, 5연속순매수일:296
# 36/775 316140-우리금융지주 Processed(처리시간:5sec, 누적시간:513sec) - 대상거래일수:2466, 5연속순매수일:13
# 37/775 030200-KT Processed(처리시간:18sec, 누적시간:531sec) - 대상거래일수:2466, 5연속순매수일:378
# 38/775 011170-롯데케미칼 Processed(처리시간:14sec, 누적시간:545sec) - 대상거래일수:2466, 5연속순매수일:239
# 39/775 024110-기업은행 Processed(처리시간:15sec, 누적시간:560sec) - 대상거래일수:2466, 5연속순매수일:257
# 40/775 009540-한국조선해양 Processed(처리시간:16sec, 누적시간:576sec) - 대상거래일수:2466, 5연속순매수일:282
# 41/775 021240-코웨이 Processed(처리시간:17sec, 누적시간:593sec) - 대상거래일수:2466, 5연속순매수일:352
# 42/775 097950-CJ제일제당 Processed(처리시간:15sec, 누적시간:608sec) - 대상거래일수:2466, 5연속순매수일:281
# 43/775 271560-오리온 Processed(처리시간:6sec, 누적시간:614sec) - 대상거래일수:2466, 5연속순매수일:40
# 44/775 006800-미래에셋대우 Processed(처리시간:15sec, 누적시간:629sec) - 대상거래일수:2466, 5연속순매수일:240
# 45/775 003670-포스코케미칼 Processed(처리시간:15sec, 누적시간:644sec) - 대상거래일수:2466, 5연속순매수일:246
# 46/775 032640-LG유플러스 Processed(처리시간:16sec, 누적시간:660sec) - 대상거래일수:2466, 5연속순매수일:300
# 47/775 009830-한화솔루션 Processed(처리시간:16sec, 누적시간:676sec) - 대상거래일수:2466, 5연속순매수일:295
# 48/775 285130-SK케미칼 Processed(처리시간:6sec, 누적시간:682sec) - 대상거래일수:2466, 5연속순매수일:39
# 49/775 180640-한진칼 Processed(처리시간:11sec, 누적시간:693sec) - 대상거래일수:2466, 5연속순매수일:174
# 50/775 035250-강원랜드 Processed(처리시간:15sec, 누적시간:708sec) - 대상거래일수:2466, 5연속순매수일:257
# 51/775 002790-아모레G Processed(처리시간:16sec, 누적시간:724sec) - 대상거래일수:2466, 5연속순매수일:295
# 52/775 086280-현대글로비스 Processed(처리시간:14sec, 누적시간:738sec) - 대상거래일수:2466, 5연속순매수일:236
# 53/775 034220-LG디스플레이 Processed(처리시간:16sec, 누적시간:754sec) - 대상거래일수:2466, 5연속순매수일:304
# 54/775 000100-유한양행 Processed(처리시간:18sec, 누적시간:772sec) - 대상거래일수:2466, 5연속순매수일:350
# 55/775 008930-한미사이언스 Processed(처리시간:17sec, 누적시간:789sec) - 대상거래일수:2466, 5연속순매수일:319
# 56/775 000720-현대건설 Processed(처리시간:15sec, 누적시간:804sec) - 대상거래일수:2466, 5연속순매수일:262
# 57/775 161390-한국타이어앤테크놀로지 Processed(처리시간:11sec, 누적시간:815sec) - 대상거래일수:2466, 5연속순매수일:177
# 58/775 267250-현대중공업지주 Processed(처리시간:8sec, 누적시간:823sec) - 대상거래일수:2466, 5연속순매수일:118
# 59/775 019170-신풍제약 Processed(처리시간:9sec, 누적시간:832sec) - 대상거래일수:2466, 5연속순매수일:78
# 60/775 004020-현대제철 Processed(처리시간:15sec, 누적시간:847sec) - 대상거래일수:2466, 5연속순매수일:264
# 61/775 011070-LG이노텍 Processed(처리시간:14sec, 누적시간:861sec) - 대상거래일수:2466, 5연속순매수일:224
# 62/775 128940-한미약품 Processed(처리시간:15sec, 누적시간:876sec) - 대상거래일수:2466, 5연속순매수일:265
# 63/775 012750-에스원 Processed(처리시간:14sec, 누적시간:890sec) - 대상거래일수:2466, 5연속순매수일:244
# 64/775 010140-삼성중공업 Processed(처리시간:15sec, 누적시간:905sec) - 대상거래일수:2466, 5연속순매수일:243
# 65/775 071050-한국금융지주 Processed(처리시간:16sec, 누적시간:921sec) - 대상거래일수:2466, 5연속순매수일:289
# 66/775 000120-CJ대한통운 Processed(처리시간:16sec, 누적시간:937sec) - 대상거래일수:2466, 5연속순매수일:277
# 67/775 005830-DB손해보험 Processed(처리시간:17sec, 누적시간:954sec) - 대상거래일수:2466, 5연속순매수일:328
# 68/775 029780-삼성카드 Processed(처리시간:16sec, 누적시간:970sec) - 대상거래일수:2466, 5연속순매수일:290
# 69/775 003490-대한항공 Processed(처리시간:15sec, 누적시간:985sec) - 대상거래일수:2466, 5연속순매수일:252
# 70/775 139480-이마트 Processed(처리시간:16sec, 누적시간:1001sec) - 대상거래일수:2466, 5연속순매수일:324
# 71/775 011790-SKC Processed(처리시간:16sec, 누적시간:1017sec) - 대상거래일수:2466, 5연속순매수일:298
# 72/775 004990-롯데지주 Processed(처리시간:17sec, 누적시간:1034sec) - 대상거래일수:2466, 5연속순매수일:323
# 73/775 006280-녹십자 Processed(처리시간:15sec, 누적시간:1049sec) - 대상거래일수:2466, 5연속순매수일:261
# 74/775 078930-GS Processed(처리시간:15sec, 누적시간:1064sec) - 대상거래일수:2466, 5연속순매수일:279
# 75/775 000080-하이트진로 Processed(처리시간:15sec, 누적시간:1079sec) - 대상거래일수:2466, 5연속순매수일:269
# 76/775 000210-대림산업 Processed(처리시간:15sec, 누적시간:1094sec) - 대상거래일수:2466, 5연속순매수일:241
# 77/775 008770-호텔신라 Processed(처리시간:15sec, 누적시간:1109sec) - 대상거래일수:2466, 5연속순매수일:259
# 78/775 012510-더존비즈온 Processed(처리시간:13sec, 누적시간:1122sec) - 대상거래일수:2466, 5연속순매수일:192
# 79/775 011780-금호석유 Processed(처리시간:16sec, 누적시간:1138sec) - 대상거래일수:2466, 5연속순매수일:300
# 80/775 241560-두산밥캣 Processed(처리시간:9sec, 누적시간:1147sec) - 대상거래일수:2466, 5연속순매수일:131
# 81/775 016360-삼성증권 Processed(처리시간:16sec, 누적시간:1163sec) - 대상거래일수:2466, 5연속순매수일:292
# 82/775 005940-NH투자증권 Processed(처리시간:15sec, 누적시간:1178sec) - 대상거래일수:2466, 5연속순매수일:250
# 83/775 003410-쌍용양회 Processed(처리시간:16sec, 누적시간:1194sec) - 대상거래일수:2466, 5연속순매수일:269
# 84/775 042660-대우조선해양 Processed(처리시간:14sec, 누적시간:1208sec) - 대상거래일수:2466, 5연속순매수일:227
# 85/775 001040-CJ Processed(처리시간:15sec, 누적시간:1223sec) - 대상거래일수:2466, 5연속순매수일:247
# 86/775 020150-일진머티리얼즈 Processed(처리시간:13sec, 누적시간:1236sec) - 대상거래일수:2466, 5연속순매수일:208
# 87/775 007070-GS리테일 Processed(처리시간:13sec, 누적시간:1249sec) - 대상거래일수:2466, 5연속순매수일:213
# 88/775 039490-키움증권 Processed(처리시간:16sec, 누적시간:1265sec) - 대상거래일수:2466, 5연속순매수일:296
# 89/775 028050-삼성엔지니어링 Processed(처리시간:14sec, 누적시간:1279sec) - 대상거래일수:2466, 5연속순매수일:204
# 90/775 336260-두산퓨얼셀 Processed(처리시간:4sec, 누적시간:1283sec) - 대상거래일수:2466, 5연속순매수일:4
# 91/775 047810-한국항공우주 Processed(처리시간:14sec, 누적시간:1297sec) - 대상거래일수:2466, 5연속순매수일:242
# 92/775 036460-한국가스공사 Processed(처리시간:16sec, 누적시간:1313sec) - 대상거래일수:2466, 5연속순매수일:290
# 93/775 003000-부광약품 Processed(처리시간:16sec, 누적시간:1329sec) - 대상거래일수:2466, 5연속순매수일:293
# 94/775 008560-메리츠증권 Processed(처리시간:18sec, 누적시간:1347sec) - 대상거래일수:2466, 5연속순매수일:388
# 95/775 009240-한샘 Processed(처리시간:14sec, 누적시간:1361sec) - 대상거래일수:2466, 5연속순매수일:213
# 96/775 004370-농심 Processed(처리시간:16sec, 누적시간:1377sec) - 대상거래일수:2466, 5연속순매수일:316
# 97/775 023530-롯데쇼핑 Processed(처리시간:16sec, 누적시간:1393sec) - 대상거래일수:2466, 5연속순매수일:297
# 98/775 034020-두산중공업 Processed(처리시간:14sec, 누적시간:1407sec) - 대상거래일수:2466, 5연속순매수일:231
# 99/775 282330-BGF리테일 Processed(처리시간:6sec, 누적시간:1413sec) - 대상거래일수:2466, 5연속순매수일:64
# 100/775 026960-동서 Processed(처리시간:17sec, 누적시간:1430sec) - 대상거래일수:2466, 5연속순매수일:326
# 101/775 006360-GS건설 Processed(처리시간:16sec, 누적시간:1446sec) - 대상거래일수:2466, 5연속순매수일:288
# 102/775 004170-신세계 Processed(처리시간:16sec, 누적시간:1462sec) - 대상거래일수:2466, 5연속순매수일:301
# 103/775 001450-현대해상 Processed(처리시간:19sec, 누적시간:1481sec) - 대상거래일수:2466, 5연속순매수일:287
# 104/775 011200-HMM Processed(처리시간:12sec, 누적시간:1493sec) - 대상거래일수:2466, 5연속순매수일:151
# 105/775 007310-오뚜기 Processed(처리시간:16sec, 누적시간:1509sec) - 대상거래일수:2466, 5연속순매수일:298
# 106/775 030000-제일기획 Processed(처리시간:14sec, 누적시간:1523sec) - 대상거래일수:2466, 5연속순매수일:211
# 107/775 081660-휠라홀딩스 Processed(처리시간:16sec, 누적시간:1539sec) - 대상거래일수:2466, 5연속순매수일:308
# 108/775 003090-대웅 Processed(처리시간:16sec, 누적시간:1555sec) - 대상거래일수:2466, 5연속순매수일:272
# 109/775 028670-팬오션 Processed(처리시간:15sec, 누적시간:1570sec) - 대상거래일수:2466, 5연속순매수일:246
# 110/775 047050-포스코인터내셔널 Processed(처리시간:15sec, 누적시간:1585sec) - 대상거래일수:2466, 5연속순매수일:240
# 111/775 000880-한화 Processed(처리시간:16sec, 누적시간:1601sec) - 대상거래일수:2466, 5연속순매수일:280
# 112/775 185750-종근당 Processed(처리시간:11sec, 누적시간:1612sec) - 대상거래일수:2466, 5연속순매수일:154
# 113/775 014680-한솔케미칼 Processed(처리시간:15sec, 누적시간:1627sec) - 대상거래일수:2466, 5연속순매수일:227
# 114/775 138930-BNK금융지주 Processed(처리시간:14sec, 누적시간:1641sec) - 대상거래일수:2466, 5연속순매수일:235
# 115/775 017800-현대엘리베이 Processed(처리시간:16sec, 누적시간:1657sec) - 대상거래일수:2466, 5연속순매수일:302
# 116/775 010120-LS ELECTRIC Processed(처리시간:15sec, 누적시간:1672sec) - 대상거래일수:2466, 5연속순매수일:249
# 117/775 042670-두산인프라코어 Processed(처리시간:16sec, 누적시간:1688sec) - 대상거래일수:2466, 5연속순매수일:268
# 118/775 000990-DB하이텍 Processed(처리시간:15sec, 누적시간:1703sec) - 대상거래일수:2466, 5연속순매수일:223
# 119/775 009420-한올바이오파마 Processed(처리시간:15sec, 누적시간:1718sec) - 대상거래일수:2466, 5연속순매수일:232

# %%
min_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
max_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
avg_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
med_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])
prob_output_df = pd.DataFrame(columns=['종목명', '종목코드', '6일째 수익률', '7일째 수익률','8일째 수익률','9일째 수익률','10일째 수익률','11일째 수익률','12일째 수익률','13일째 수익률','14일째 수익률','15일째 수익률'])


file_list = os.listdir(rootPath+"/Kosdaq/")
kosdaq_file_list_csv = [file for file in file_list if file.endswith(".csv")]
total_day = len(kosdaq_file_list_csv)
total_process_time = 0
for i,v in enumerate(kosdaq_file_list_csv):
  try:
    code = v[:6]
    name = v[7:-4]
    start_time = time.time()
    dfMerged = getKosdaqMergedTab(rootPath, code, name, start_date, end_date)
    dfCount = accumConsecutiveCount(dfMerged)
    dfRevenue = computeRevenue(dfCount)
    if dfRevenue.shape[0] > 0:
      # file_path = rootPath + '/output/raw_' + code + "_" + name + ".csv"
      # dfRevenue.to_csv(file_path, index = False, header=True)
      tmp_series_max = pd.Series(getSummary_max(code, name, dfRevenue), index = max_output_df.columns)
      max_output_df = max_output_df.append(tmp_series_max, ignore_index=True)

      tmp_series_min = pd.Series(getSummary_min(code, name, dfRevenue), index = min_output_df.columns)
      min_output_df = min_output_df.append(tmp_series_min, ignore_index=True)

      tmp_series_avg = pd.Series(getSummary_avg(code, name, dfRevenue), index = avg_output_df.columns)
      avg_output_df = avg_output_df.append(tmp_series_avg, ignore_index=True)

      tmp_series_med = pd.Series(getSummary_med(code, name, dfRevenue), index = med_output_df.columns)
      med_output_df = med_output_df.append(tmp_series_med, ignore_index=True)

      tmp_series_prob = pd.Series(getSummary_prob(code, name, dfRevenue), index = prob_output_df.columns)
      prob_output_df = prob_output_df.append(tmp_series_prob, ignore_index=True)

    end_time = time.time()
    processed_time = int(end_time - start_time)
    total_process_time += processed_time
    print("{}/{} {}-{} Processed(처리시간:{}sec, 누적시간:{}sec) - 대상거래일수:{}, 5연속순매수일:{}".format(i+1, total_day, code, name, processed_time, total_process_time, dfMerged.shape[0], dfRevenue.shape[0]))
  except Exception as e: 
    print(e)
    continue    
    
file_path_max = rootPath + '/output/summary_5days_kosdaq_max.csv'
max_output_df.to_csv(file_path_max, index = False, header=True)

file_path_min = rootPath + '/output/summary_5days_kosdaq_min.csv'
min_output_df.to_csv(file_path_min, index = False, header=True)

file_path_avg = rootPath + '/output/summary_5days_kospi_avg.csv'
avg_output_df.to_csv(file_path_avg, index = False, header=True)

file_path_med = rootPath + '/output/summary_5days_kosdaq_med.csv'
med_output_df.to_csv(file_path_med, index = False, header=True)

file_path_prob = rootPath + '/output/summary_5days_kosdaq_prob.csv'
prob_output_df.to_csv(file_path_prob, index = False, header=True)
